# %% [markdown]
# # House Prices Project
#
# **Dataset**: [House Prices - Advanced Regression Techniques](https://www.kaggle.com/competitions/house-prices-advanced-regression-techniques/data)
#
# **Goal**: Predict the sale price of houses using statistical and machine learning methods.

# %% [markdown]
# ---
# ## Setup and Imports

# %%
from math import sqrt
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
import statsmodels.graphics.gofplots
from statsmodels.formula.api import ols
import statsmodels.api as sm
# Add your additional imports as needed
from sklearn.metrics import r2_score

# import torch

pd.set_option('display.max_columns', 100)
# %matplotlib inline

# %% [markdown]
# ---
# ## Load Data

# %%
train = pd.read_csv('data/train.csv', encoding='utf-8')
test = pd.read_csv('data/test.csv', encoding='utf-8')

print(f'Training set: {train.shape[0]} rows, {train.shape[1]} columns')
print(f'Test set: {test.shape[0]} rows, {test.shape[1]} columns')

train.head()
# Out:
# Training set: 1460 rows, 81 columns
# Test set: 1459 rows, 80 columns
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     2Story            7            5       2003
# 1       Norm     1Fam     1Story            6            8       1976
# 2       Norm     1Fam     2Story            7            5       2001
# 3       Norm     1Fam     2Story            7            5       1915
# 4       Norm     1Fam     2Story            8            5       2000
#
#    YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0          2003     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1          1976     Gable  CompShg     MetalSd     MetalSd        NaN
# 2          2002     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 3          1970     Gable  CompShg     Wd Sdng     Wd Shng        NaN
# 4          2000     Gable  CompShg     VinylSd     VinylSd    BrkFace
#
#    MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 0       196.0        Gd        TA      PConc       Gd       TA           No
# 1         0.0        TA        TA     CBlock       Gd       TA           Gd
# 2       162.0        Gd        TA      PConc       Gd       TA           Mn
# 3         0.0        TA        TA     BrkTil       TA       Gd           No
# 4       350.0        Gd        TA      PConc       Gd       TA           Av
#
#   BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          GLQ         706          Unf           0        150          856
# 1          ALQ         978          Unf           0        284         1262
# 2          GLQ         486          Unf           0        434          920
# 3          ALQ         216          Unf           0        540          756
# 4          GLQ         655          Unf           0        490         1145
#
#   Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 0    GasA        Ex          Y      SBrkr       856       854             0
# 1    GasA        Ex          Y      SBrkr      1262         0             0
# 2    GasA        Ex          Y      SBrkr       920       866             0
# 3    GasA        Gd          Y      SBrkr       961       756             0
# 4    GasA        Ex          Y      SBrkr      1145      1053             0
#
#    GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 0       1710             1             0         2         1             3
# 1       1262             0             1         2         0             3
# 2       1786             1             0         2         1             3
# 3       1717             1             0         1         0             3
# 4       2198             1             0         2         1             4
#
#    KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu  \
# 0             1          Gd             8        Typ           0         NaN
# 1             1          TA             6        Typ           1          TA
# 2             1          Gd             6        Typ           1          TA
# 3             1          Gd             7        Typ           1          Gd
# 4             1          Gd             9        Typ           1          TA
#
#   GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# 0     Attchd       2003.0          RFn           2         548         TA
# 1     Attchd       1976.0          RFn           2         460         TA
# 2     Attchd       2001.0          RFn           2         608         TA
# 3     Detchd       1998.0          Unf           3         642         TA
# 4     Attchd       2000.0          RFn           3         836         TA
#
#   GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 0         TA          Y           0           61              0          0
# 1         TA          Y         298            0              0          0
# 2         TA          Y           0           42              0          0
# 3         TA          Y           0           35            272          0
# 4         TA          Y         192           84              0          0
#
#    ScreenPorch  PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold  \
# 0            0         0    NaN   NaN         NaN        0       2    2008
# 1            0         0    NaN   NaN         NaN        0       5    2007
# 2            0         0    NaN   NaN         NaN        0       9    2008
# 3            0         0    NaN   NaN         NaN        0       2    2006
# 4            0         0    NaN   NaN         NaN        0      12    2008
#
#   SaleType SaleCondition  SalePrice
# 0       WD        Normal     208500
# 1       WD        Normal     181500
# 2       WD        Normal     223500
# 3       WD       Abnorml     140000
# 4       WD        Normal     250000

# %%
# Explore the target variable
print(train['SalePrice'].describe())
var_s = train['SalePrice'].var()

fig, axes = plt.subplots(1, 1, figsize=(12, 4))
axes.hist(train['SalePrice'], bins=50, edgecolor='black')
axes.set_title('SalePrice Distribution')
axes.set_xlabel('SalePrice')
plt.tight_layout()
plt.show()

print(f'Skewness: {train["SalePrice"].skew():.3f}')
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64
# 6311111264.297448
# Skewness: 1.883

# %% [markdown]
# The data is heavily skewed, what kind of transformation can we apply to make it more normal?

# %% [markdown]
# ---
# ## Part 1: Classical Statistical Inference
#
# Apply basic statistical methods to explore the data:
# - **Sample mean and variance** of `SalePrice` and key features
# - **Confidence intervals** for the mean SalePrice
# - **Hypothesis testing** — e.g. is the mean SalePrice significantly different from \$180,000? Is the distribution of the transformed `SalePrice` normal (Shapiro-Wilk)?
# - Visualize distributions and support your conclusions with plots

# %%
# Transforming prices into logs to have a normal distribution. Adding them to the train dataframe
train["SalePrice_log"] = np.log(train['SalePrice'])
sales_price = train['SalePrice_log']

# mean, variance, SD
mean_sales_price = np.mean(sales_price)
n = len(sales_price)
var_sales_price = sum((x - mean_sales_price)**2 for x in sales_price)/(n-1)
std_sales_price = sqrt(var_sales_price)

print(sales_price.describe())

# Shapiro test doesn't properly work on large samples
print(stats.shapiro(sales_price))

# Shapiro test on a random sample from sales_log with n=100
print(stats.shapiro(sales_price.sample(100)))
# Out:
# count    1460.000000
# mean       12.024051
# std         0.399452
# min        10.460242
# 25%        11.775097
# 50%        12.001505
# 75%        12.273731
# max        13.534473
# Name: SalePrice_log, dtype: float64
# ShapiroResult(statistic=np.float64(0.9912067503807811), pvalue=np.float64(1.1490615527264654e-07))
# ShapiroResult(statistic=np.float64(0.9573446996628227), pvalue=np.float64(0.002612167834076214))

# %%
# To prove that we now have a normal distribution let's do a QQ plot
stats.probplot(sales_price, dist="norm", plot=plt)
plt.show()

# %%
# Confidence interval for the mean of log price
alpha = 0.05
df = n - 1
t_crit = stats.t.ppf(1-alpha/2, df)
margin_error = t_crit * (std_sales_price/sqrt(n))
lower_limit = mean_sales_price - margin_error
upper_limit = mean_sales_price + margin_error
p = stats.t.cdf(t_crit, df)

# %%
# PLOT
fig, ax = plt.subplots()
plt.hist(sales_price)
x = np.linspace(np.min(sales_price), np.max(sales_price), 1000)

t_dist = stats.t(df, loc=mean_sales_price, scale=std_sales_price)
t_but_normal = stats.norm(mean_sales_price, std_sales_price)
ax2 = ax.twinx()
ax.grid(False)
ax2.plot(x, t_dist.pdf(x), color='lightgreen', label="T Distribution")
ax2.plot(x, t_but_normal.pdf(x), color='blue', linestyle="--", label="Normal")
ax2.set_yscale('log')
ax.set_title('SalePrice Distribution')
ax.set_xlabel('SalePrice')
plt.axvline(lower_limit, color='blue', linestyle='--', linewidth=1)
plt.axvline(upper_limit, color='blue', linestyle='--', linewidth=1)


print(f"Mean's confidence interval at 95% CI: [{lower_limit}, {upper_limit}]")
print(f'Skewness: {train["SalePrice_log"].skew():.3f}')
plt.show()
# Out:
# Mean's confidence interval at 95% CI: [12.003544164729277, 12.04455763748949]
# Skewness: 0.121

# %%
x = np.linspace(np.min(sales_price), np.max(sales_price), 1000)
t_pdf = stats.t.pdf(x, df, loc=mean_sales_price, scale=std_sales_price)
plt.plot(x, t_pdf, color='lightgreen', linewidth=2)
plt.axvline(mean_sales_price, color='green', linestyle='--', linewidth=2)
plt.grid(False)

# %%
# Outliers
plt.boxplot(train["SalePrice_log"])
plt.show()

# %%
# CI for variance
a = stats.chi2.ppf(alpha/2, df)
b = stats.chi2.ppf(1-alpha/2, df)

# ((n-1)*sample_var)/b < pop_var < ((n-1)*sample_var)/a
var_lower_limit = (df*var_sales_price)/b
var_upper_limit = (df*var_sales_price)/a

print(f"Confidence Interval (95%) for the variance: [{var_lower_limit}, {var_upper_limit}]")
# Out:
# Confidence Interval (95%) for the variance: [0.14858771791596836, 0.17180448306911694]

# %% [markdown]
# - **Hypothesis testing** — is the mean SalePrice significantly different from \$180,000?
# - H0 : mean = \$180,000
# - H1 : mean != \$180,000

# %%
h0_mean = np.log(180000)
print(h0_mean)
t_h0 = (mean_sales_price - h0_mean)/ (sqrt(var_sales_price)/sqrt(n))
p_CI_mean = 2* (1 - stats.t.cdf(abs(t_h0), df))
print(p_CI_mean)
print(f"p-val < alpha: {p_CI_mean < alpha}")
print("So we reject the null hypothesis")
# Out:
# 12.100712129872347
# 3.7125857943465235e-13
# p-val < alpha: True
# So we reject the null hypothesis

# %% [markdown]
# - **Hypothesis testing** — the mean of SalePrice doesn't have significant variations between the ExterQual = EX ant the other levels of ExterQual (Gd, TA or Fa).
#
# We have to run multiple tests.
# 1. We compare EX with Good
# - H0 : mean_EX - mean_Gd = 0
# - H1 : mean_EX - mean_Gd != 0

# %%
Ex = train.loc[train["ExterQual"] == "Ex", "SalePrice_log"]
Gd = train.loc[train["ExterQual"] == "Gd", "SalePrice_log"]

mean_Ex = Ex.mean()
mean_Gd = Gd.mean()
diff_means = mean_Ex - mean_Gd

n_Ex = len(Ex)
n_Gd = len(Gd)
df_ExGd = n_Ex + n_Gd - 2

var_Ex = sum((x - mean_Ex)**2 for x in Ex)/(n_Ex-1)
var_Gd = sum((x - mean_Gd)**2 for x in Gd)/(n_Gd-1)
sample_var_pool = ((n_Ex-1) * var_Ex + (n_Gd-1) * var_Gd)/ df_ExGd

t_diff = diff_means/ sqrt(sample_var_pool * (1/n_Ex + 1/n_Gd))
t_crit = stats.t.ppf(1-alpha/2, df_ExGd)
margin_error = t_crit * sqrt(sample_var_pool * (1/n_Ex + 1/n_Gd))

lower_limit = diff_means - margin_error
upper_limit = diff_means + margin_error

print(f"Interval: [{lower_limit},{upper_limit}]. Because 0 is not in the interval, we can reject the null hypothesis")
# Out:
# Interval: [0.3696651243584748,0.5358585899114827]. Because 0 is not in the interval, we can reject the null hypothesis

# %% [markdown]
# 2. We compare EX with TA (Typical/Average)
# - H0 : mean_EX - mean_TA = 0
# - H1 : mean_EX - mean_TA != 0

# %%
TA = train.loc[train["ExterQual"] == "TA", "SalePrice_log"]
mean_TA = TA.mean()
diff_means = mean_Ex - mean_TA

n_TA = len(TA)
df_ExTA = n_Ex + n_TA - 2

var_TA = sum((x - mean_TA)**2 for x in TA)/(n_TA-1)
sample_var_pool = ((n_Ex-1) * var_Ex + (n_TA-1) * var_TA)/ df_ExTA

t_diff = diff_means/ sqrt(sample_var_pool * (1/n_Ex + 1/n_TA))
t_crit = stats.t.ppf(1-alpha/2, df_ExTA)
margin_error = t_crit * sqrt(sample_var_pool * (1/n_Ex + 1/n_TA))

lower_limit = diff_means - margin_error
upper_limit = diff_means + margin_error

print(f"Interval: [{lower_limit},{upper_limit}]. Because 0 is not in the interval, we can reject the null hypothesis")
# Out:
# Interval: [0.8433676535135881,1.008750552914141]. Because 0 is not in the interval, we can reject the null hypothesis

# %% [markdown]
# 3. We compare EX with FA (Fair)
# - H0 : mean_EX - mean_Fa = 0
# - H1 : mean_EX - mean_Fa != 0

# %%
Fa = train.loc[train["ExterQual"] == "Fa", "SalePrice_log"]
mean_Fa = Fa.mean()
diff_means = mean_Ex - mean_Fa

n_Fa = len(Fa)
df_ExFa = n_Ex + n_Fa - 2

var_Fa = sum((x - mean_Fa)**2 for x in Fa)/(n_Fa-1)
sample_var_pool = ((n_Ex-1) * var_Ex + (n_Fa-1) * var_Fa)/ df_ExFa

t_diff = diff_means/ sqrt(sample_var_pool * (1/n_Ex + 1/n_Fa))
t_crit = stats.t.ppf(1-alpha/2, df_ExFa)
margin_error = t_crit * sqrt(sample_var_pool * (1/n_Ex + 1/n_Fa))

lower_limit = diff_means - margin_error
upper_limit = diff_means + margin_error

print(f"Interval: [{lower_limit},{upper_limit}]. Because 0 is not in the interval, we can reject the null hypothesis")
# Out:
# Interval: [1.2528048839347037,1.6662018426459084]. Because 0 is not in the interval, we can reject the null hypothesis

# %% [markdown]
# The following plot shows the prices distributions grouped by the External Quality levels

# %%
plt.scatter(train["SalePrice_log"],train["ExterQual"])
plt.axvline(mean_sales_price, color='blue', linewidth=2)
for line in train["SalePrice_log"].groupby(train["ExterQual"]).agg("mean"):
    plt.axvline(line,linestyle='--')
plt.grid(False)
train["SalePrice_log"].groupby(train["ExterQual"]).agg(["mean", "min", "max", "std", "count"])
# Out:
#                 mean        min        max       std  count
# ExterQual
# Ex         12.764044  11.982929  13.534473  0.325699     52
# Fa         11.304541  10.578980  12.206073  0.406416     14
# Gd         12.311282  10.858999  13.521139  0.285985    488
# TA         11.837985  10.460242  12.850555  0.293697    906

# %% [markdown]
# ---
# ## Part 2: ANOVA — Finding Significant Features
#
# Use ANOVA to determine which of the following **10 features** have a statistically significant effect on the transformed SalePrice.
#
# **Given features (10):**
#
# | # | Feature | Levels | Description |
# |---|---|---|---|
# | 1 | `OverallQual` | 1–10 | Overall material and finish quality |
# | 2 | `ExterQual` | Po, Fa, TA, Gd, Ex | Exterior material quality |
# | 3 | `BsmtQual` | None, Po, Fa, TA, Gd, Ex | Basement height quality |
# | 4 | `KitchenQual` | Po, Fa, TA, Gd, Ex | Kitchen quality |
# | 5 | `FireplaceQu` | None, Po, Fa, TA, Gd, Ex | Fireplace quality |
# | 6 | `CentralAir` | N, Y | Central air conditioning |
# | 7 | `LotShape` | IR3, IR2, IR1, Reg | General shape of property |
# | 8 | `LandSlope` | Sev, Mod, Gtl | Slope of property |
# | 9 | `MoSold` | 1–12 | Month sold |
# | 10 | `YrSold` | 2006–2010 | Year sold |
#
# **Tasks:**
# 1. Extract these features into a dataframe and run **one-way ANOVA** on each
# 2. Identify which features are significant (p < 0.05)
# 3. Run a **two-way ANOVA** to test for interaction effects between pairs of significant features
# 4. Use **Tukey HSD** post-hoc tests where appropriate
# 5. Summarize: which features and interactions are significant?

# %%
features = ['OverallQual', 'ExterQual', 'BsmtQual', 'KitchenQual','FireplaceQu', 'CentralAir', 'LotShape', 'LandSlope', 'MoSold', 'YrSold']

df_anova = train[features + ["SalePrice_log"]].copy()
for col in features:
    if df_anova[col].dtype == "object" or df_anova[col].isnull().any():
        df_anova[col] = df_anova[col].fillna("None")

results = []
for col in features:
    groups = [group["SalePrice_log"].values for name, group in df_anova.groupby(col)]
    f_stat, p_val = stats.f_oneway(*groups)
    results.append({
        "Feature": col,
        "F-Statistic": f_stat,
        "p-value": p_val,
        "Significant (0.05)": p_val < 0.05
    })

anova_r = pd.DataFrame(results).sort_values(by="F-Statistic", ascending=False)
print(anova_r)
# Out:
#        Feature  F-Statistic        p-value  Significant (0.05)
# 1    ExterQual   415.303357  6.935425e-195                True
# 3  KitchenQual   393.320196  4.441486e-187                True
# 0  OverallQual   332.166377   0.000000e+00                True
# 2     BsmtQual   300.392324  2.031282e-188                True
# 5   CentralAir   205.666987   9.855628e-44                True
# 4  FireplaceQu   131.198459  6.963458e-115                True
# 6     LotShape    46.728762   7.856968e-29                True
# 7    LandSlope     1.083039   3.388375e-01               False
# 8       MoSold     0.993740   4.496616e-01               False
# 9       YrSold     0.738616   5.656374e-01               False

# %%
# Fit the one-way ANOVA model
model = ols('SalePrice_log ~ ExterQual', data=train).fit()

# ANOVA table
anova_table = sm.stats.anova_lm(model, typ=2)
print(anova_table)

# Residuals and fitted values
residuals = model.resid
fitted = model.fittedvalues
plt.figure()
plt.scatter(train["ExterQual"], residuals)
plt.axhline(0, color="red")
plt.xlabel("Exterior quality")
plt.ylabel("Residuals")
plt.title("Residuals vs ExQual")
plt.show()
# Out:
#                sum_sq      df           F         PR(>F)
# ExterQual  107.349496     3.0  415.303357  6.935425e-195
# Residual   125.451163  1456.0         NaN            NaN

# %% [markdown]
# Running an ANOVA test on all the features

# %%
all_features = train.columns.tolist()
all_features.remove("SalePrice_log")
all_features.remove("SalePrice")
all_features.remove("Id")

df_anova_total = train.copy()
for col in all_features:
    if df_anova_total[col].dtype == "object" or df_anova_total[col].isnull().any():
        df_anova_total[col] = df_anova_total[col].fillna("None")

results = []
for col in all_features:
    groups = [group["SalePrice_log"].values for name, group in df_anova_total.groupby(col)]
    f_stat, p_val = stats.f_oneway(*groups)
    results.append({
        "Feature": col,
        "F-Statistic": f_stat,
        "p-value": p_val,
        "Significant": p_val < 0.05
    })

anova_t = pd.DataFrame(results).sort_values(by="F-Statistic", ascending=False)
anova_t[anova_t["Significant"]]
# Out:
#           Feature  F-Statistic        p-value  Significant
# 26      ExterQual   415.303357  6.935425e-195         True
# 52    KitchenQual   393.320196  4.441486e-187         True
# 60     GarageCars   349.636936  5.539585e-211         True
# 16    OverallQual   332.166377   0.000000e+00         True
# 29       BsmtQual   300.392324  2.031282e-188         True
# ..            ...          ...            ...          ...
# 74        MiscVal     1.785866   1.759180e-02         True
# 67  EnclosedPorch     1.776628   1.735024e-06         True
# 43       2ndFlrSF     1.540164   2.887863e-08         True
# 33     BsmtFinSF1     1.376995   8.290390e-06         True
# 36      BsmtUnfSF     1.278458   4.942658e-04         True
#
# [70 rows x 4 columns]

# %%
# Between groups: External Quality
ex_qual_means = train.groupby("ExterQual")["SalePrice_log"].mean()
ex_qual_ss = sum(len(train[train["ExterQual"] == level])* (ex_qual_means[level] - mean_sales_price)**2 for level in ex_qual_means.index)

# Between groups: Neighborhood
ne_means = train.groupby("Neighborhood")["SalePrice_log"].mean()
ne_ss = sum(len(train[train["Neighborhood"] == level]) * (ne_means[level] - mean_sales_price)**2 for level in ne_means.index)

# Interaction ExQual * Neighborhood NON FUNZIA
interaction_ss = 0
for ex_qual_level in ex_qual_means.index:
    for ne_level in ne_means.index:
        subset = train[(train["ExterQual"] == ex_qual_level) & (train["Neighborhood"] == ne_level)]

        interaction_mean = subset["SalePrice_log"].mean()
        print(f"subbset: {subset}. interaction: {interaction_mean}")
        interaction_ss += len(subset) * (interaction_mean - ex_qual_means[ex_qual_level] - ne_means[ne_level] + mean_sales_price) ** 2
        print(f"{len(subset)} * {interaction_mean} - {ex_qual_means[ex_qual_level]} - {ne_means[ne_level]} + {mean_sales_price} ** 2")
# SST
sst = sum((train["SalePrice_log"] - mean_sales_price) **2 )

# SSE
sse = sst - ex_qual_ss - ne_ss - interaction_ss

# df
df_ex_qual = len(ex_qual_means) - 1
df_ne = len(ne_means) - 1
df_interaction = df_ex_qual * df_ne
df_error = len(train) - (df_ex_qual + df_ne - df_interaction +1)

# MS
ms_ex_qual = ex_qual_ss/df_ex_qual
ms_ne = ne_ss/df_ne
ms_interaction = interaction_ss/df_interaction
mse = sse / df_error

# F-stat
f_ex_qual = ms_ex_qual/mse
f_ne = ms_ne/mse
f_interaction = ms_interaction/mse

# p-values
p_ex_qual = 1 - stats.f.cdf(f_ex_qual, df_ex_qual, df_error)
p_ne = 1 - stats.f.cdf(f_ne, df_ne, df_error)
p_interaction = 1 - stats.f.cdf(f_interaction, df_interaction, df_error)

anova_table = pd.DataFrame({
    "Source": ["ExQual", "Neighborhood", "ExQual*Neighborhood", "Error"],
    "SS": [ex_qual_ss, ne_ss, interaction_ss, sse],
    "df": [df_ex_qual, df_ne, df_interaction, df_error],
    "MS": [ms_ex_qual, ms_ne, ms_interaction, mse],
    "F": [f_ex_qual, f_ne, df_interaction, np.nan],
    "p-value": [p_ex_qual, p_ne, p_interaction, np.nan],
})

anova_table
# Out:
# subbset: Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotFrontage, LotArea, Street, Alley, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, PoolQC, Fence, MiscFeature, MiscVal, MoSold, YrSold, SaleType, SaleCondition, SalePrice, SalePrice_log]
# Index: []. interaction: nan
# 0 * nan - 12.764044312670817 - 12.169415617992842 + 12.024050901109383 ** 2
# subbset: Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotFrontage, LotArea, Street, Alley, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, PoolQC, Fence, MiscFeature, MiscVal, MoSold, YrSold, SaleType, SaleCondition, SalePrice, SalePrice_log]
# Index: []. interaction: nan
# 0 * nan - 12.764044312670817 - 11.82653598019212 + 12.024050901109383 ** 2
# subbset: Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotFrontage, LotArea, Street, Alley, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, PoolQC, Fence, MiscFeature, MiscVal, MoSold, YrSold, SaleType, SaleCondition, SalePrice, SalePrice_log]
# Index: []. interaction: nan
# 0 * nan - 12.764044312670817 - 11.547864429415947 + 12.024050901109383 ** 2
# subbset: Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotFrontage, LotArea, Street, Alley, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, PoolQC, Fence, MiscFeature, MiscVal, MoSold, YrSold, SaleType, SaleCondition, SalePrice, SalePrice_log]
# Index: []. interaction: nan
# 0 * nan - 12.764044312670817 - 11.679726905369055 + 12.024050901109383 ** 2
# subbset: Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotFrontage, LotArea, Street, Alley, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, PoolQC, Fence, MiscFeature, MiscVal, MoSold, YrSold, SaleType, SaleCondition, SalePrice, SalePrice_log]
# Index: []. interaction: nan
# 0 * nan - 12.764044312670817 - 12.23990008471337 + 12.024050901109383 ** 2
# subbset: Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotFrontage, LotArea, Street, Alley, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, PoolQC, Fence, MiscFeature, MiscVal, MoSold, YrSold, SaleType, SaleCondition, SalePrice, SalePrice_log]
# Index: []. interaction: nan
# 0 * nan - 12.764044312670817 - 12.163641307701866 + 12.024050901109383 ** 2
# subbset:         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1181  1182         120       RM         64.0     5587   Pave   NaN      IR1
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 1181         HLS    AllPub    Inside       Mod      Crawfor       Norm
# 1457         Lvl    AllPub    Inside       Gtl      Crawfor       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 1181       Norm   TwnhsE     1Story            8            5       2008
# 1457       Norm     1Fam     2Story            7            9       1941
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 1181          2008       Hip  CompShg     CemntBd     CmentBd      Stone
# 1457          2006     Gable  CompShg     CemntBd     CmentBd        NaN
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 1181       186.0        Ex        TA      PConc       Ex       TA
# 1457         0.0        Ex        Gd      Stone       TA       Gd
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# 1181           Gd          GLQ        1480          Unf           0
# 1457           No          GLQ         275          Unf           0
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# 1181        120         1600    GasA        Ex          Y      SBrkr
# 1457        877         1152    GasA        Ex          Y      SBrkr
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# 1181      1652         0             0       1652             1             1
# 1457      1188      1152             0       2340             0             0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# 1181         2         0             2             1          Gd
# 1457         2         0             4             1          Gd
#
#       TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt  \
# 1181             5        Typ           1          Gd     Attchd       2008.0
# 1457             9        Typ           2          Gd     Attchd       1941.0
#
#      GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# 1181          Fin           2         482         TA         TA          Y
# 1457          RFn           1         252         TA         TA          Y
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 1181         162           53              0        153            0
# 1457           0           60              0          0            0
#
#       PoolArea PoolQC  Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# 1181         0    NaN    NaN         NaN        0      11    2008      New
# 1457         0    NaN  GdPrv        Shed     2500       5    2010       WD
#
#      SaleCondition  SalePrice  SalePrice_log
# 1181       Partial     392500      12.880292
# 1457        Normal     266500      12.493130  . interaction: 12.68671066939632
# 2 * 12.68671066939632 - 12.764044312670817 - 12.206658874866637 + 12.024050901109383 ** 2
# subbset:         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 523    524          60       RL        130.0    40094   Pave   NaN      IR1
# 724    725          20       RL         86.0    13286   Pave   NaN      IR1
# 1298  1299          60       RL        313.0    63887   Pave   NaN      IR3
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 523          Bnk    AllPub    Inside       Gtl      Edwards       PosN
# 724          Lvl    AllPub    Inside       Gtl      Edwards       Norm
# 1298         Bnk    AllPub    Corner       Gtl      Edwards      Feedr
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 523        PosN     1Fam     2Story           10            5       2007
# 724        Norm     1Fam     1Story            9            5       2007
# 1298       Norm     1Fam     2Story           10            5       2008
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 523           2008       Hip  CompShg     CemntBd     CmentBd      Stone
# 724           2008       Hip  CompShg     CemntBd     CmentBd      Stone
# 1298          2008       Hip  ClyTile      Stucco      Stucco      Stone
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 523        762.0        Ex        TA      PConc       Ex       TA
# 724        340.0        Ex        TA      PConc       Ex       TA
# 1298       796.0        Ex        TA      PConc       Ex       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# 523            Gd          GLQ        2260          Unf           0
# 724            No          GLQ        1234          Unf           0
# 1298           Gd          GLQ        5644          Unf           0
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# 523         878         3138    GasA        Ex          Y      SBrkr
# 724         464         1698    GasA        Ex          Y      SBrkr
# 1298        466         6110    GasA        Ex          Y      SBrkr
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# 523       3138      1538             0       4676             1             0
# 724       1698         0             0       1698             1             0
# 1298      4692       950             0       5642             2             0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# 523          3         1             3             1          Ex
# 724          2         0             3             1          Ex
# 1298         2         1             3             1          Ex
#
#       TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt  \
# 523             11        Typ           1          Gd    BuiltIn       2007.0
# 724              8        Typ           1          Gd     Attchd       2007.0
# 1298            12        Typ           3          Gd     Attchd       2008.0
#
#      GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# 523           Fin           3         884         TA         TA          Y
# 724           Fin           3         768         TA         TA          Y
# 1298          Fin           2        1418         TA         TA          Y
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 523          208          406              0          0            0
# 724          327           64              0          0            0
# 1298         214          292              0          0            0
#
#       PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# 523          0    NaN   NaN         NaN        0      10    2007      New
# 724          0    NaN   NaN         NaN        0       2    2009       WD
# 1298       480     Gd   NaN         NaN        0       1    2008      New
#
#      SaleCondition  SalePrice  SalePrice_log
# 523        Partial     184750      12.126759
# 724         Normal     320000      12.676076
# 1298       Partial     160000      11.982929  . interaction: 12.261921402600771
# 3 * 12.261921402600771 - 12.764044312670817 - 11.712312038339492 + 12.024050901109383 ** 2
# subbset:         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 95      96          60       RL          NaN     9765   Pave   NaN      IR2
# 1388  1389          20       RL         42.0    14892   Pave   NaN      IR1
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 95           Lvl    AllPub    Corner       Gtl      Gilbert       Norm
# 1388         HLS    AllPub   CulDSac       Gtl      Gilbert       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 95         Norm     1Fam     2Story            6            8       1993
# 1388       Norm     1Fam     1Story            9            5       2006
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 95            1993     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1388          2007     Gable  CompShg     VinylSd     VinylSd      Stone
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 95          68.0        Ex        Gd      PConc       Gd       Gd
# 1388       160.0        Ex        TA      PConc       Ex       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# 95             No          ALQ         310          Unf           0
# 1388           Gd          GLQ        1320          Unf           0
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# 95          370          680    GasA        Gd          Y      SBrkr
# 1388        426         1746    GasA        Ex          Y      SBrkr
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# 95         680       790             0       1470             0             0
# 1388      1746         0             0       1746             1             0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# 95           2         1             3             1          TA
# 1388         2         0             3             1          Ex
#
#       TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt  \
# 95               6        Typ           1          TA    BuiltIn       1993.0
# 1388             7        Typ           2          Gd     Attchd       2006.0
#
#      GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# 95            Fin           2         420         TA         TA          Y
# 1388          Fin           3         758         TA         TA          Y
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 95           232           63              0          0            0
# 1388         201           39              0          0            0
#
#       PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# 95           0    NaN   NaN        Shed      480       4    2009       WD
# 1388         0    NaN   NaN         NaN        0      10    2009       WD
#
#      SaleCondition  SalePrice  SalePrice_log
# 95          Normal     185000      12.128111
# 1388        Normal     377500      12.841326  . interaction: 12.48471847586584
# 2 * 12.48471847586584 - 12.764044312670817 - 12.15580329874186 + 12.024050901109383 ** 2
# subbset: Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotFrontage, LotArea, Street, Alley, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, PoolQC, Fence, MiscFeature, MiscVal, MoSold, YrSold, SaleType, SaleCondition, SalePrice, SalePrice_log]
# Index: []. interaction: nan
# 0 * nan - 12.764044312670817 - 11.446889031955806 + 12.024050901109383 ** 2
# subbset: Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotFrontage, LotArea, Street, Alley, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, PoolQC, Fence, MiscFeature, MiscVal, MoSold, YrSold, SaleType, SaleCondition, SalePrice, SalePrice_log]
# Index: []. interaction: nan
# 0 * nan - 12.764044312670817 - 11.47452224569399 + 12.024050901109383 ** 2
# subbset: Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotFrontage, LotArea, Street, Alley, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, PoolQC, Fence, MiscFeature, MiscVal, MoSold, YrSold, SaleType, SaleCondition, SalePrice, SalePrice_log]
# Index: []. interaction: nan
# 0 * nan - 12.764044312670817 - 11.933947606576133 + 12.024050901109383 ** 2
# subbset:       Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 919  920          20       RL         87.0    11029   Pave   NaN      IR1
# 980  981          85       RL          NaN    12122   Pave   NaN      IR1
#
#     LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 919         Lvl    AllPub    Corner       Gtl        NAmes       Norm
# 980         Lvl    AllPub    Corner       Gtl        NAmes       Norm
#
#     Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 919       Norm     1Fam     1Story            6            8       1958
# 980       Norm     1Fam     SFoyer            7            9       1961
#
#      YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 919          2002       Hip  CompShg     MetalSd     MetalSd        NaN
# 980          2007     Gable  CompShg     CemntBd     CmentBd      Stone
#
#      MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 919         0.0        Ex        TA     CBlock       Gd       TA           No
# 980       210.0        Ex        TA     CBlock       TA       TA           Av
#
#     BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 919          ALQ         528          BLQ         411        245         1184
# 980          ALQ         867          Unf           0         77          944
#
#     Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 919    GasA        Ex          Y      SBrkr      1414         0             0
# 980    GasA        Gd          Y      SBrkr       999         0             0
#
#      GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 919       1414             1             0         1         0             3
# 980        999             1             0         1         0             3
#
#      KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces  \
# 919             1          TA             6       Min1           1
# 980             1          Ex             6        Typ           0
#
#     FireplaceQu GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea  \
# 919          TA     Attchd       1990.0          Unf           2         601
# 980         NaN     Attchd       1961.0          RFn           2         588
#
#     GarageQual GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  \
# 919         TA         TA          Y           0           51              0
# 980         TA         TA          Y         144           76              0
#
#      3SsnPorch  ScreenPorch  PoolArea PoolQC Fence MiscFeature  MiscVal  \
# 919          0          190         0    NaN   NaN         NaN        0
# 980          0            0         0    NaN   NaN         NaN        0
#
#      MoSold  YrSold SaleType SaleCondition  SalePrice  SalePrice_log
# 919       5    2008       WD        Normal     176500      12.081076
# 980       7    2008       WD        Normal     178400      12.091783  . interaction: 12.086429827241767
# 2 * 12.086429827241767 - 12.764044312670817 - 11.868044676362079 + 12.024050901109383 ** 2
# subbset: Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotFrontage, LotArea, Street, Alley, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, PoolQC, Fence, MiscFeature, MiscVal, MoSold, YrSold, SaleType, SaleCondition, SalePrice, SalePrice_log]
# Index: []. interaction: nan
# 0 * nan - 12.764044312670817 - 11.866477387059547 + 12.024050901109383 ** 2
# subbset:       Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 745  746          60       RL          NaN     8963   Pave   NaN      IR1
#
#     LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 745         Lvl    AllPub    Inside       Gtl       NWAmes       Norm
#
#     Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 745       Norm     1Fam     2Story            8            9       1976
#
#      YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 745          1996       Hip  CompShg     VinylSd     VinylSd    BrkFace
#
#      MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 745       289.0        Ex        Gd     CBlock       TA       Gd           No
#
#     BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 745          GLQ         575          ALQ          80        487         1142
#
#     Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 745    GasA        Ex          Y      SBrkr      1175      1540             0
#
#      GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 745       2715             0             1         3         1             4
#
#      KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces  \
# 745             1          Gd            11        Typ           2
#
#     FireplaceQu GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea  \
# 745          TA    BuiltIn       1994.0          Fin           2         831
#
#     GarageQual GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  \
# 745         TA         TA          Y           0          204              0
#
#      3SsnPorch  ScreenPorch  PoolArea PoolQC Fence MiscFeature  MiscVal  \
# 745          0            0         0    NaN   NaN         NaN        0
#
#      MoSold  YrSold SaleType SaleCondition  SalePrice  SalePrice_log
# 745       7    2008       WD        Normal     299800      12.610871  . interaction: 12.610870864650634
# 1 * 12.610870864650634 - 12.764044312670817 - 12.130608869884238 + 12.024050901109383 ** 2
# subbset:         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 691    692          60       RL        104.0    21535   Pave   NaN      IR1
# 1373  1374          20       RL          NaN    11400   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 691          Lvl    AllPub    Corner       Gtl      NoRidge       Norm
# 1373         Lvl    AllPub    Inside       Gtl      NoRidge       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 691        Norm     1Fam     2Story           10            6       1994
# 1373       Norm     1Fam     1Story           10            5       2001
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 691           1995     Gable  WdShngl     HdBoard     HdBoard    BrkFace
# 1373          2002       Hip  CompShg     VinylSd     VinylSd    BrkFace
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 691       1170.0        Ex        TA      PConc       Ex       TA
# 1373       705.0        Ex        TA      PConc       Ex       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# 691            Gd          GLQ        1455          Unf           0
# 1373           Gd          GLQ        1282          Unf           0
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# 691         989         2444    GasA        Ex          Y      SBrkr
# 1373       1351         2633    GasA        Ex          Y      SBrkr
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# 691       2444      1872             0       4316             0             1
# 1373      2633         0             0       2633             1             0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# 691          3         1             4             1          Ex
# 1373         2         1             2             1          Ex
#
#       TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt  \
# 691             10        Typ           2          Ex     Attchd       1994.0
# 1373             8        Typ           2          Gd     Attchd       2001.0
#
#      GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# 691           Fin           3         832         TA         TA          Y
# 1373          RFn           3         804         TA         TA          Y
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 691          382           50              0          0            0
# 1373         314          140              0          0            0
#
#       PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# 691          0    NaN   NaN         NaN        0       1    2007       WD
# 1373         0    NaN   NaN         NaN        0       3    2007       WD
#
#      SaleCondition  SalePrice  SalePrice_log
# 691         Normal     755000      13.534473
# 1373        Normal     466500      13.053013  . interaction: 13.29374316375035
# 2 * 13.29374316375035 - 12.764044312670817 - 12.676000124908816 + 12.024050901109383 ** 2
# subbset:         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 11      12          60       RL         85.0    11924   Pave   NaN      IR1
# 34      35         120       RL         60.0     7313   Pave   NaN      Reg
# 45      46         120       RL         61.0     7658   Pave   NaN      Reg
# 224    225          20       RL        103.0    13472   Pave   NaN      Reg
# 238    239          20       RL         93.0    12030   Pave   NaN      Reg
# 278    279          20       RL        107.0    14450   Pave   NaN      Reg
# 343    344         120       RL         63.0     8849   Pave   NaN      IR1
# 349    350          60       RL         56.0    20431   Pave   NaN      IR2
# 350    351         120       RL         68.0     7820   Pave   NaN      IR1
# 389    390          60       RL         96.0    12474   Pave   NaN      Reg
# 440    441          20       RL        105.0    15431   Pave   NaN      Reg
# 477    478          60       RL        105.0    13693   Pave   NaN      Reg
# 515    516          20       RL         94.0    12220   Pave   NaN      Reg
# 527    528          60       RL         67.0    14948   Pave   NaN      IR1
# 581    582          20       RL         98.0    12704   Pave   NaN      Reg
# 591    592          60       RL         97.0    13478   Pave   NaN      IR1
# 618    619          20       RL         90.0    11694   Pave   NaN      Reg
# 640    641         120       RL         62.0    12677   Pave   NaN      IR1
# 798    799          60       RL        104.0    13518   Pave   NaN      Reg
# 803    804          60       RL        107.0    13891   Pave   NaN      Reg
# 825    826          20       RL        114.0    14803   Pave   NaN      Reg
# 898    899          20       RL        100.0    12919   Pave   NaN      IR1
# 987    988          20       RL         83.0    10159   Pave   NaN      IR1
# 994    995          20       RL         96.0    12456   Pave   NaN      Reg
# 1058  1059          60       RL         96.0    11308   Pave   NaN      IR1
# 1228  1229         120       RL         65.0     8769   Pave   NaN      Reg
# 1243  1244          20       RL        107.0    13891   Pave   NaN      Reg
# 1437  1438          20       RL         96.0    12444   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 11           Lvl    AllPub    Inside       Gtl      NridgHt       Norm
# 34           Lvl    AllPub    Inside       Gtl      NridgHt       Norm
# 45           Lvl    AllPub    Inside       Gtl      NridgHt       Norm
# 224          Lvl    AllPub    Inside       Gtl      NridgHt       Norm
# 238          Lvl    AllPub    Inside       Gtl      NridgHt       Norm
# 278          Lvl    AllPub    Inside       Gtl      NridgHt       Norm
# 343          Lvl    AllPub    Inside       Gtl      NridgHt       Norm
# 349          Lvl    AllPub    Inside       Gtl      NridgHt       Norm
# 350          Lvl    AllPub    Inside       Gtl      NridgHt       Norm
# 389          Lvl    AllPub    Inside       Gtl      NridgHt       Norm
# 440          Lvl    AllPub    Inside       Gtl      NridgHt       Norm
# 477          Lvl    AllPub    Inside       Gtl      NridgHt       Norm
# 515          Lvl    AllPub    Inside       Gtl      NridgHt       Norm
# 527          Lvl    AllPub    Inside       Gtl      NridgHt       Norm
# 581          Lvl    AllPub    Inside       Gtl      NridgHt       Norm
# 591          Lvl    AllPub    Corner       Gtl      NridgHt       Norm
# 618          Lvl    AllPub    Inside       Gtl      NridgHt       Norm
# 640          Lvl    AllPub    Inside       Gtl      NridgHt       Norm
# 798          Lvl    AllPub    Inside       Gtl      NridgHt       Norm
# 803          Lvl    AllPub    Inside       Gtl      NridgHt       Norm
# 825          Lvl    AllPub    Inside       Gtl      NridgHt       PosN
# 898          Lvl    AllPub    Inside       Gtl      NridgHt       Norm
# 987          Lvl    AllPub    Inside       Gtl      NridgHt       Norm
# 994          Lvl    AllPub       FR2       Gtl      NridgHt       Norm
# 1058         Lvl    AllPub    Inside       Gtl      NridgHt       Norm
# 1228         Lvl    AllPub    Corner       Gtl      NridgHt       Norm
# 1243         Lvl    AllPub    Inside       Gtl      NridgHt       Norm
# 1437         Lvl    AllPub       FR2       Gtl      NridgHt       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 11         Norm     1Fam     2Story            9            5       2005
# 34         Norm   TwnhsE     1Story            9            5       2005
# 45         Norm   TwnhsE     1Story            9            5       2005
# 224        Norm     1Fam     1Story           10            5       2003
# 238        Norm     1Fam     1Story            8            5       2007
# 278        Norm     1Fam     1Story            9            5       2006
# 343        Norm   TwnhsE     1Story            9            5       2005
# 349        Norm     1Fam     2Story            9            5       2005
# 350        Norm   TwnhsE     1Story            9            5       2007
# 389        Norm     1Fam     2Story           10            5       2007
# 440        Norm     1Fam     1Story           10            5       2008
# 477        Norm     1Fam     2Story            9            5       2006
# 515        Norm     1Fam     1Story           10            5       2009
# 527        Norm     1Fam     2Story            9            5       2008
# 581        Norm     1Fam     1Story            8            5       2008
# 591        Norm     1Fam     2Story           10            5       2008
# 618        Norm     1Fam     1Story            9            5       2007
# 640        Norm   TwnhsE     1Story            8            5       2003
# 798        Norm     1Fam     2Story            9            5       2008
# 803        Norm     1Fam     2Story            9            5       2008
# 825        PosN     1Fam     1Story           10            5       2007
# 898        Norm     1Fam     1Story            9            5       2009
# 987        Norm     1Fam     1Story            9            5       2009
# 994        Norm     1Fam     1Story           10            5       2006
# 1058       Norm     1Fam     2Story            9            5       2008
# 1228       Norm   TwnhsE     1Story            9            5       2008
# 1243       Norm     1Fam     1Story           10            5       2006
# 1437       Norm     1Fam     1Story            8            5       2008
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 11            2006       Hip  CompShg     WdShing     Wd Shng      Stone
# 34            2005       Hip  CompShg     MetalSd     MetalSd    BrkFace
# 45            2005       Hip  CompShg     MetalSd     MetalSd    BrkFace
# 224           2003       Hip  CompShg     VinylSd     VinylSd    BrkFace
# 238           2007       Hip  CompShg     VinylSd     VinylSd    BrkFace
# 278           2007     Gable  CompShg     CemntBd     CmentBd    BrkFace
# 343           2005       Hip  CompShg     MetalSd     MetalSd    BrkFace
# 349           2006       Hip  CompShg     CemntBd     CmentBd    BrkFace
# 350           2007       Hip  CompShg     MetalSd     MetalSd    BrkFace
# 389           2008     Gable  CompShg     VinylSd     VinylSd      Stone
# 440           2008       Hip  CompShg     VinylSd     VinylSd      Stone
# 477           2006       Hip  CompShg     VinylSd     VinylSd    BrkFace
# 515           2009       Hip  CompShg     CemntBd     CmentBd    BrkFace
# 527           2008       Hip  CompShg     VinylSd     VinylSd      Stone
# 581           2009       Hip  CompShg     VinylSd     VinylSd    BrkFace
# 591           2008     Gable  CompShg     CemntBd     CmentBd      Stone
# 618           2007       Hip  CompShg     CemntBd     CmentBd    BrkFace
# 640           2004       Hip  CompShg     MetalSd     MetalSd    BrkFace
# 798           2009       Hip  CompShg     VinylSd     VinylSd      Stone
# 803           2009       Hip  CompShg     VinylSd     VinylSd      Stone
# 825           2008       Hip  CompShg     CemntBd     CmentBd    BrkFace
# 898           2010       Hip  CompShg     VinylSd     VinylSd      Stone
# 987           2010       Hip  CompShg     VinylSd     VinylSd      Stone
# 994           2007       Hip  CompShg     CemntBd     CmentBd      Stone
# 1058          2008     Gable  CompShg     VinylSd     VinylSd      Stone
# 1228          2008       Hip  CompShg     MetalSd     MetalSd    BrkFace
# 1243          2006     Gable  CompShg     VinylSd     VinylSd        NaN
# 1437          2008       Hip  CompShg     VinylSd     VinylSd      Stone
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 11         286.0        Ex        TA      PConc       Ex       TA
# 34         246.0        Ex        TA      PConc       Ex       TA
# 45         412.0        Ex        TA      PConc       Ex       TA
# 224        922.0        Ex        TA      PConc       Ex       TA
# 238        254.0        Ex        TA      PConc       Ex       TA
# 278        315.0        Ex        TA      PConc       Ex       TA
# 343        616.0        Ex        TA      PConc       Ex       TA
# 349        870.0        Ex        TA      PConc       Ex       TA
# 350        362.0        Ex        TA      PConc       Ex       TA
# 389        272.0        Ex        TA      PConc       Ex       TA
# 440        200.0        Ex        TA      PConc       Ex       TA
# 477        772.0        Ex        TA      PConc       Gd       TA
# 515        305.0        Ex        TA     CBlock       Ex       TA
# 527        268.0        Ex        TA      PConc       Ex       TA
# 581        306.0        Ex        TA      PConc       Ex       TA
# 591        420.0        Ex        TA      PConc       Ex       TA
# 618        452.0        Ex        TA      PConc       Ex       TA
# 640        472.0        Ex        TA      PConc       Ex       TA
# 798        860.0        Ex        TA      PConc       Ex       TA
# 803        424.0        Ex        TA      PConc       Ex       TA
# 825        816.0        Ex        TA      PConc       Ex       TA
# 898        760.0        Ex        TA      PConc       Ex       TA
# 987        450.0        Ex        TA      PConc       Ex       TA
# 994        230.0        Ex        TA      PConc       Ex       TA
# 1058       154.0        Ex        TA      PConc       Ex       TA
# 1228       766.0        Ex        TA      PConc       Ex       TA
# 1243         NaN        Ex        TA      PConc       Ex       Gd
# 1437       426.0        Ex        TA      PConc       Ex       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# 11             No          GLQ         998          Unf           0
# 34             No          GLQ        1153          Unf           0
# 45             No          GLQ         456          Unf           0
# 224            Gd          GLQ          56          Unf           0
# 238            No          Unf           0          Unf           0
# 278            Gd          Unf           0          Unf           0
# 343            No          GLQ          28          Unf           0
# 349            No          GLQ        1410          Unf           0
# 350            No          Unf           0          Unf           0
# 389            Av          GLQ        1280          Unf           0
# 440            Gd          GLQ        1767          ALQ         539
# 477            Av          Unf           0          Unf           0
# 515            No          GLQ        1436          Unf           0
# 527            Av          GLQ        1330          Unf           0
# 581            No          Unf           0          Unf           0
# 591            Gd          GLQ        1338          Unf           0
# 618            Av          GLQ          48          Unf           0
# 640            Gd          GLQ        1218          Unf           0
# 798            No          Unf           0          Unf           0
# 803            Gd          Unf           0          Unf           0
# 825            Av          GLQ        1636          Unf           0
# 898            Gd          GLQ        2188          Unf           0
# 987            Av          GLQ        1646          Unf           0
# 994            Gd          GLQ        1172          Unf           0
# 1058           Av          GLQ         936          Unf           0
# 1228           No          GLQ        1540          Unf           0
# 1243           Gd          GLQ        1386          Unf           0
# 1437           Av          GLQ        1336          Unf           0
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# 11          177         1175    GasA        Ex          Y      SBrkr
# 34          408         1561    GasA        Ex          Y      SBrkr
# 45         1296         1752    GasA        Ex          Y      SBrkr
# 224        2336         2392    GasA        Ex          Y      SBrkr
# 238        1694         1694    GasA        Ex          Y      SBrkr
# 278        2121         2121    GasA        Ex          Y      SBrkr
# 343        1656         1684    GasA        Ex          Y      SBrkr
# 349         438         1848    GasA        Ex          Y      SBrkr
# 350        1869         1869    GasA        Ex          Y      SBrkr
# 389         402         1682    GasA        Ex          Y      SBrkr
# 440         788         3094    GasA        Ex          Y      SBrkr
# 477        2153         2153    GasA        Ex          Y      SBrkr
# 515         570         2006    GasA        Ex          Y      SBrkr
# 527         122         1452    GasA        Ex          Y      SBrkr
# 581        2042         2042    GasA        Ex          Y      SBrkr
# 591         384         1722    GasA        Ex          Y      SBrkr
# 618        1774         1822    GasA        Ex          Y      SBrkr
# 640         300         1518    GasA        Ex          Y      SBrkr
# 798        1926         1926    GasA        Ex          Y      SBrkr
# 803        1734         1734    GasA        Ex          Y      SBrkr
# 825         442         2078    GasA        Ex          Y      SBrkr
# 898         142         2330    GasA        Ex          Y      SBrkr
# 987         284         1930    GasA        Ex          Y      SBrkr
# 994         528         1700    GasA        Ex          Y      SBrkr
# 1058        168         1104    GasA        Ex          Y      SBrkr
# 1228        162         1702    GasA        Ex          Y      SBrkr
# 1243        690         2076    GasA        Ex          Y      SBrkr
# 1437        596         1932    GasA        Ex          Y      SBrkr
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# 11        1182      1142             0       2324             1             0
# 34        1561         0             0       1561             1             0
# 45        1752         0             0       1752             1             0
# 224       2392         0             0       2392             0             0
# 238       1694         0             0       1694             0             0
# 278       2121         0             0       2121             0             0
# 343       1684         0             0       1684             0             0
# 349       1848       880             0       2728             1             0
# 350       1869         0             0       1869             0             0
# 389       1742       590             0       2332             1             0
# 440       2402         0             0       2402             1             0
# 477       2069       574             0       2643             0             0
# 515       2020         0             0       2020             1             0
# 527       1476      1237             0       2713             1             0
# 581       2042         0             0       2042             0             0
# 591       1728       568             0       2296             1             0
# 618       1828         0             0       1828             0             0
# 640       1518         0             0       1518             0             0
# 798       1966      1174             0       3140             0             0
# 803       1734      1088             0       2822             0             0
# 825       2084         0             0       2084             1             0
# 898       2364         0             0       2364             1             0
# 987       1940         0             0       1940             1             0
# 994       1718         0             0       1718             1             0
# 1058      1130      1054             0       2184             1             0
# 1228      1702         0             0       1702             1             0
# 1243      2076         0             0       2076             1             0
# 1437      1932         0             0       1932             1             0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# 11           3         0             4             1          Ex
# 34           2         0             2             1          Ex
# 45           2         0             2             1          Ex
# 224          2         0             3             1          Ex
# 238          2         0             3             1          Gd
# 278          2         1             3             1          Ex
# 343          2         0             2             1          Ex
# ...
# 1379       Norm     1Fam       SLvl            5            5       2006
# 1396       Norm     1Fam     1Story            5            5       1948
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 41            1959     Gable  CompShg     VinylSd     VinylSd        NaN
# 174           1986     Gable  CompShg     VinylSd     Plywood      Stone
# 313           1965       Hip  CompShg     BrkFace     BrkFace        NaN
# 335           1965     Gable  CompShg     Plywood     Plywood        NaN
# 429           1988     Gable  CompShg     HdBoard     HdBoard        NaN
# 572           2009     Gable  CompShg     VinylSd     VinylSd        NaN
# 695           1987     Gable  CompShg     HdBoard     HdBoard    BrkFace
# 944           1958     Gable  CompShg     HdBoard     HdBoard    BrkFace
# 1180          1991     Gable  CompShg     MetalSd     MetalSd        NaN
# 1184          1963       Hip  CompShg     MetalSd     MetalSd    BrkFace
# 1281          1990       Hip  CompShg     HdBoard     HdBoard    BrkFace
# 1379          2007     Gable  CompShg     VinylSd     VinylSd        NaN
# 1396          1950     Gable  CompShg     Wd Sdng     Wd Sdng        NaN
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 41           0.0        TA        Gd     CBlock       TA       TA
# 174        132.0        TA        TA     CBlock       Gd       Fa
# 313          0.0        TA        TA     CBlock       Gd       TA
# 335          0.0        TA        TA     CBlock       TA       TA
# 429          0.0        TA        TA     CBlock       Gd       TA
# 572          0.0        TA        TA      PConc       Ex       TA
# 695         72.0        TA        TA     CBlock       Gd       Gd
# 944        541.0        TA        TA     CBlock       TA       TA
# 1180         0.0        TA        TA       Wood       Gd       TA
# 1184       226.0        TA        TA     CBlock       TA       TA
# 1281        54.0        TA        TA     CBlock       Gd       TA
# 1379         0.0        TA        TA      PConc       Gd       TA
# 1396         0.0        TA        TA     CBlock       TA       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# 41             Gd          BLQ         967          Unf           0
# 174            No          ALQ        1398          LwQ         208
# 313            Gd          ALQ        1236          Rec         820
# 335            Gd          ALQ        1249          BLQ         147
# 429            Mn          GLQ        1005          Unf           0
# 572            Av          Unf           0          Unf           0
# 695            No          GLQ         980          LwQ          40
# 944            No          GLQ         111          Rec         354
# 1180           No          LwQ        1216          Unf           0
# 1184           Gd          Rec        1159          Unf           0
# 1281           No          ALQ        1053          Unf           0
# 1379           No          Unf           0          Unf           0
# 1396           Av          BLQ         353          Rec         334
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# 41          383         1350    GasA        Gd          Y      SBrkr
# 174           0         1606    GasA        TA          Y      SBrkr
# 313          80         2136    GasW        TA          Y      SBrkr
# 335         103         1499    GasA        Ex          Y      SBrkr
# 429         387         1392    GasA        TA          Y      SBrkr
# 572         846          846    GasA        Gd          Y      SBrkr
# 695          92         1112    GasA        Gd          Y      SBrkr
# 944         354          819    GasA        Gd          Y      FuseA
# 1180          0         1216    GasA        Ex          Y      SBrkr
# 1184        413         1572    GasA        Gd          Y      SBrkr
# 1281        256         1309    GasA        TA          Y      SBrkr
# 1379        384          384    GasA        Gd          Y        NaN
# 1396         60          747    GasA        TA          Y      SBrkr
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# 41        1328         0             0       1328             0             1
# 174       1651         0             0       1651             1             0
# 313       2036         0             0       2036             2             0
# 335       1619       167             0       1786             2             0
# 429       1412         0             0       1412             1             0
# 572        846       846             0       1692             0             0
# 695       1137         0             0       1137             1             0
# 944       1344         0             0       1344             0             1
# 1180      1298      1216             0       2514             0             0
# 1184      1572         0             0       1572             1             0
# 1281      1339         0             0       1339             1             0
# 1379       754       640             0       1394             0             0
# 1396      1687         0             0       1687             1             0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# 41           1         1             2             1          TA
# 174          2         0             3             1          TA
# 313          2         0             3             1          TA
# 335          2         0             3             1          TA
# 429          2         0             3             1          Gd
# 572          2         1             3             1          Gd
# 695          2         0             2             1          Gd
# 944          1         0             3             1          Gd
# 1180         2         1             4             1          TA
# 1184         1         1             3             1          TA
# 1281         2         0             2             1          TA
# 1379         2         1             3             1          Gd
# 1396         1         0             3             1          TA
#
#       TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt  \
# 41               5        Typ           2          Gd     Attchd       1959.0
# 174              7       Min2           1          TA     Attchd       1986.0
# 313              8        Typ           2          Gd     Attchd       1965.0
# 335              7        Typ           2          Gd     Attchd       1965.0
# 429              6        Typ           1          TA     Attchd       1988.0
# 572              6        Typ           0         NaN     Attchd       2009.0
# 695              5        Typ           1          TA     Attchd       1987.0
# 944              7        Typ           1          Gd    Basment       1958.0
# 1180             8        Typ           0         NaN     Attchd       1990.0
# 1184             5        Typ           2          TA     2Types       1963.0
# 1281             6        Typ           1          TA     Attchd       1990.0
# 1379             7        Typ           0         NaN    BuiltIn       2007.0
# 1396             7       Min1           2          TA     Detchd       1966.0
#
#      GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# 41            RFn           1         308         TA         TA          P
# 174           Fin           2         616         TA         TA          Y
# 313           RFn           2         513         TA         TA          Y
# 335           Fin           2         529         TA         TA          Y
# 429           Unf           2         576         TA         TA          Y
# 572           RFn           2         650         TA         TA          Y
# 695           Unf           2         551         TA         TA          Y
# 944           RFn           2         525         TA         TA          Y
# 1180          Fin           2         693         TA         TA          Y
# 1184          RFn           3         995         TA         TA          Y
# 1281          Fin           2         484         Gd         Gd          Y
# 1379          Fin           2         400         TA         TA          Y
# 1396          Unf           2         572         TA         TA          N
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 41             0          104              0          0            0
# 174          192            0              0          0            0
# 313            0            0              0          0            0
# 335          670            0              0          0            0
# 429            0            0            169          0            0
# 572          208          114              0          0            0
# 695          125            0              0          0            0
# 944            0          118              0          0          233
# 1180           0            0              0          0            0
# 1184           0          263              0          0          263
# 1281           0           58              0          0           90
# 1379         100            0              0          0            0
# 1396           0            0             50          0            0
#
#       PoolArea PoolQC  Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# 41           0    NaN    NaN         NaN        0       7    2007       WD
# 174          0    NaN    NaN         NaN        0      11    2008       WD
# 313          0    NaN    NaN         NaN        0       6    2009       WD
# 335          0    NaN    NaN        Shed      700       8    2008       WD
# 429          0    NaN    NaN         NaN        0       3    2009       WD
# 572          0    NaN    NaN         NaN        0       7    2009      New
# 695          0    NaN    NaN         NaN        0       7    2006       WD
# 944          0    NaN    NaN         NaN        0       1    2009      COD
# 1180         0    NaN  GdPrv         NaN        0       4    2006       WD
# 1184         0    NaN    NaN         NaN        0       5    2007       WD
# 1281         0    NaN    NaN         NaN        0       7    2006       WD
# 1379         0    NaN    NaN         NaN        0       5    2008       WD
# 1396         0    NaN    NaN         NaN        0       6    2010       WD
#
#      SaleCondition  SalePrice  SalePrice_log
# 41          Normal     170000      12.043554
# 174         Normal     184000      12.122691
# 313         Normal     375000      12.834681
# 335         Normal     228950      12.341259
# 429         Normal     175000      12.072541
# 572        Partial     224500      12.321631
# 695         Normal     176000      12.078239
# 944        Abnorml     137500      11.831379
# 1180        Normal     250000      12.429216
# 1184        Normal     186700      12.137258
# 1281        Normal     180000      12.100712
# 1379        Normal     167500      12.028739
# 1396        Normal     160000      11.982929  . interaction: 12.178833081965402
# 13 * 12.178833081965402 - 11.837985209456953 - 12.363455360340872 + 12.024050901109383 ** 2
# subbset:         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 160    161          20       RL          NaN    11120   Pave   NaN      IR1
# 1164  1165          80       RL          NaN    16157   Pave   NaN      IR1
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 1            Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 160          Lvl    AllPub   CulDSac       Gtl      Veenker       Norm
# 1164         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 1          Norm     1Fam     1Story            6            8       1976
# 160        Norm     1Fam     1Story            6            6       1984
# 1164       Norm     1Fam       SLvl            5            7       1978
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 1             1976     Gable  CompShg     MetalSd     MetalSd        NaN
# 160           1984     Gable  CompShg     Plywood     Plywood        NaN
# 1164          1978     Gable  CompShg     Plywood     Plywood        NaN
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 1            0.0        TA        TA     CBlock       Gd       TA
# 160          0.0        TA        TA      PConc       Gd       TA
# 1164         0.0        TA        TA      PConc       Gd       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# 1              Gd          ALQ         978          Unf           0
# 160            No          BLQ         660          Unf           0
# 1164           Gd          ALQ         680          Rec         391
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# 1           284         1262    GasA        Ex          Y      SBrkr
# 160         572         1232    GasA        TA          Y      SBrkr
# 1164        289         1360    GasA        Ex          Y      SBrkr
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# 1         1262         0             0       1262             0             1
# 160       1232         0             0       1232             0             0
# 1164      1432         0             0       1432             1             0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# 1            2         0             3             1          TA
# 160          2         0             3             1          TA
# 1164         1         1             2             1          Gd
#
#       TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt  \
# 1                6        Typ           1          TA     Attchd       1976.0
# 160              6        Typ           0         NaN     Attchd       1984.0
# 1164             5        Typ           1          TA     Attchd       1978.0
#
#      GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# 1             RFn           2         460         TA         TA          Y
# 160           Unf           2         516         TA         TA          Y
# 1164          Unf           2         588         TA         TA          Y
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 1            298            0              0          0            0
# 160            0            0              0          0            0
# 1164         168          180              0          0            0
#
#       PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# 1            0    NaN   NaN         NaN        0       5    2007       WD
# 160          0    NaN   NaN         NaN        0       6    2008       WD
# 1164         0    NaN   NaN         NaN        0       6    2007       WD
#
#      SaleCondition  SalePrice  SalePrice_log
# 1           Normal     181500      12.109011
# 160         Normal     162500      11.998433
# 1164        Normal     194000      12.175613  . interaction: 12.094352550494811
# 3 * 12.094352550494811 - 11.837985209456953 - 12.344175869139775 + 12.024050901109383 ** 2
#                 Source          SS    df         MS     F  p-value
# 0               ExQual  107.349496     3  35.783165   NaN      NaN
# 1         Neighborhood  132.884425    24   5.536851   NaN      NaN
# 2  ExQual*Neighborhood         NaN    72        NaN  72.0      NaN
# 3                Error         NaN  1504        NaN   NaN      NaN

# %% [markdown]
# ---
# ## Part 3: 2^k Factorial Design
#
# Pick k binary (or binarized) factors from the significant features found in Part 2 and apply a factorial design analysis. For example you could binarize ordinal features into High/Low groups and study their joint effects.
#
# **Tasks:**
# - Select k factors (e.g. k=2 or k=3) and define High/Low levels
# - Compute group means for all 2^k combinations
# - Analyze main effects and interaction effects
# - Visualize with interaction plots

# %% [markdown]
# ---
# ## Part 4: Parametric Regression
#
# Build a regression model using only the **significant ordinal features** identified by ANOVA (Part 2) plus the **2 numerical features**: `GrLivArea` and `TotalBsmtSF`.
#
# **Tasks:**
# - Encode ordinal features numerically (map quality levels to integers)
# - Fit a linear regression model (OLS)
# - Analyze the model: R², coefficient significance, residual plots
# - Optionally try regularized regression (Ridge, Lasso) and compare
# - Apply ANOVA on the regression model to assess factor contributions

# %% [markdown]
# ---
# ## Part 5: Non-Parametric Model (Neural Network)
#
# Build a neural network regression model using **all** available features to predict SalePrice. This is also the model that produces your `submission.csv` for Kaggle scoring.
#
# **Tasks:**
# - Preprocess all features: handle missing values, encode categoricals, scale numerics
# - Build and train a neural network (e.g. `sklearn.neural_network.MLPRegressor` or PyTorch)
# - Evaluate on training data (RMSE, R²) and analyze residuals
# - Generate predictions for the test set and save as `submission.csv`
#
# **Important:** The Kaggle RMSE score is evaluated on the predictions from this model.
